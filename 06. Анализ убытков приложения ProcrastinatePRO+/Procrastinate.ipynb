# %% [markdown]
# <h1>Проектная работа по анализу бизнес показателей<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-подготовка-их-к-анализу" data-toc-modified-id="Загрузка-данных-и-подготовка-их-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных и подготовка их к анализу</a></span><ul class="toc-item"><li><span><a href="#Ознакамливаюсь-со-структурой-данных" data-toc-modified-id="Ознакамливаюсь-со-структурой-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Ознакамливаюсь со структурой данных</a></span></li><li><span><a href="#Определяю-наличие-пропусков-и-формат-данных" data-toc-modified-id="Определяю-наличие-пропусков-и-формат-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Определяю наличие пропусков и формат данных</a></span></li><li><span><a href="#Привожу-название-столбцов-к-нижнему-регистру" data-toc-modified-id="Привожу-название-столбцов-к-нижнему-регистру-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Привожу название столбцов к нижнему регистру</a></span></li><li><span><a href="#Переименовываю-название-колонок-с-датами-и-ID" data-toc-modified-id="Переименовываю-название-колонок-с-датами-и-ID-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Переименовываю название колонок с датами и ID</a></span></li><li><span><a href="#Привожу-временные-колонки--во-временной-формат" data-toc-modified-id="Привожу-временные-колонки--во-временной-формат-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Привожу временные колонки  во временной формат</a></span></li><li><span><a href="#Проверяю-на-наличие-дубликатов-явных" data-toc-modified-id="Проверяю-на-наличие-дубликатов-явных-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Проверяю на наличие дубликатов явных</a></span></li><li><span><a href="#Проверяю-наличие-неявных" data-toc-modified-id="Проверяю-наличие-неявных-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Проверяю наличие неявных</a></span></li></ul></li><li><span><a href="#Задаю-функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии." data-toc-modified-id="Задаю-функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Задаю функции для расчёта и анализа LTV, ROI, удержания и конверсии.</a></span><ul class="toc-item"><li><span><a href="#Проводим-когортный-анализ" data-toc-modified-id="Проводим-когортный-анализ-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Проводим когортный анализ</a></span><ul class="toc-item"><li><span><a href="#Создаём-профили-пользователей" data-toc-modified-id="Создаём-профили-пользователей-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Создаём профили пользователей</a></span></li><li><span><a href="#Подсчитываем-Retention-Rate" data-toc-modified-id="Подсчитываем-Retention-Rate-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Подсчитываем Retention Rate</a></span></li><li><span><a href="#Расчет-конверсии-CR" data-toc-modified-id="Расчет-конверсии-CR-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Расчет конверсии CR</a></span></li><li><span><a href="#Подсчет-LTV-и-ROI,-CAC" data-toc-modified-id="Подсчет-LTV-и-ROI,-CAC-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Подсчет LTV и ROI, CAC</a></span></li></ul></li><li><span><a href="#Визуализация-когортного-анализа" data-toc-modified-id="Визуализация-когортного-анализа-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Визуализация когортного анализа</a></span><ul class="toc-item"><li><span><a href="#filter_data()-—-для-сглаживания-данных" data-toc-modified-id="filter_data()-—-для-сглаживания-данных-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>filter_data() — для сглаживания данных</a></span></li><li><span><a href="#Функция-для-построения-графика-Retention-Rate" data-toc-modified-id="Функция-для-построения-графика-Retention-Rate-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Функция для построения графика Retention Rate</a></span></li><li><span><a href="#функция-для-построения-графика-конверсии" data-toc-modified-id="функция-для-построения-графика-конверсии-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>функция для построения графика конверсии</a></span></li><li><span><a href="#функция--для-визуализации-LTV-и-ROI" data-toc-modified-id="функция--для-визуализации-LTV-и-ROI-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>функция  для визуализации LTV и ROI</a></span></li></ul></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Минимальная-и-максимальная-дата-привлечения-пользователей." data-toc-modified-id="Минимальная-и-максимальная-дата-привлечения-пользователей.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Минимальная и максимальная дата привлечения пользователей.</a></span></li><li><span><a href="#Определяю-страны-с-большей-долей-пользователей-совершивших-покупки" data-toc-modified-id="Определяю-страны-с-большей-долей-пользователей-совершивших-покупки-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Определяю страны с большей долей пользователей совершивших покупки</a></span></li><li><span><a href="#Какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи" data-toc-modified-id="Какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи</a></span></li><li><span><a href="#Рекламные-источники-привлечения-и--каналы,-из-которых-пришло-больше-всего-платящих-пользователей" data-toc-modified-id="Рекламные-источники-привлечения-и--каналы,-из-которых-пришло-больше-всего-платящих-пользователей-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Рекламные источники привлечения и  каналы, из которых пришло больше всего платящих пользователей</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Общая-сумма-расходов-на-маркетинг" data-toc-modified-id="Общая-сумма-расходов-на-маркетинг-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Общая сумма расходов на маркетинг</a></span></li><li><span><a href="#Cколько-денег-потратили-на-каждый-источник" data-toc-modified-id="Cколько-денег-потратили-на-каждый-источник-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Cколько денег потратили на каждый источник</a></span></li><li><span><a href="#Визуализация-динамики-изменения-расходов-во-времени-(по-неделям-и-месяцам)-по-каждому-источнику" data-toc-modified-id="Визуализация-динамики-изменения-расходов-во-времени-(по-неделям-и-месяцам)-по-каждому-источнику-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Визуализация динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику</a></span></li><li><span><a href="#Средняя-цена-привлечения-одного-пользователя-(CAC)-из-каждого-источника" data-toc-modified-id="Средняя-цена-привлечения-одного-пользователя-(CAC)-из-каждого-источника-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Средняя цена привлечения одного пользователя (CAC) из каждого источника</a></span></li></ul></li><li><span><a href="#Оцените-окупаемость-рекламы" data-toc-modified-id="Оцените-окупаемость-рекламы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оцените окупаемость рекламы</a></span><ul class="toc-item"><li><span><a href="#Визуализирую-данные-с-помощью-графических-функций" data-toc-modified-id="Визуализирую-данные-с-помощью-графических-функций-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Визуализирую данные с помощью графических функций</a></span></li><li><span><a href="#Проверка-конверсию-пользователей-и-динамику-её-изменения" data-toc-modified-id="Проверка-конверсию-пользователей-и-динамику-её-изменения-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Проверка конверсию пользователей и динамику её изменения</a></span></li><li><span><a href="#Анализируем-окупаемость-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Анализируем-окупаемость-рекламы-с-разбивкой-по-устройствам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Анализируем окупаемость рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Анализируем-окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Анализируем-окупаемость-рекламы-с-разбивкой-по-странам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Анализируем окупаемость рекламы с разбивкой по странам</a></span></li><li><span><a href="#Анализируем-окупаемость-рекламы-с-разбивкой-по-каналам" data-toc-modified-id="Анализируем-окупаемость-рекламы-с-разбивкой-по-каналам-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Анализируем окупаемость рекламы с разбивкой по каналам</a></span><ul class="toc-item"><li><span><a href="#Что-если-сравнить-каналы-US-и-других-стран?" data-toc-modified-id="Что-если-сравнить-каналы-US-и-других-стран?-5.5.1"><span class="toc-item-num">5.5.1&nbsp;&nbsp;</span>Что если сравнить каналы US и других стран?</a></span></li></ul></li></ul></li><li><span><a href="#Общие-выводы" data-toc-modified-id="Общие-выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общие выводы</a></span></li></ul></div>

# %% [markdown]
# # О проекте
# Вы — маркетинговый аналитик развлекательного приложения Procrastinate Pro+. Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки. Ваша задача — разобраться в причинах и помочь компании выйти в плюс.
#
#
# Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
#
# * лог сервера с данными об их посещениях,
# * выгрузка их покупок за этот период,
# * рекламные расходы.
#
#
# Вам предстоит изучить:
# * откуда приходят пользователи и какими устройствами они пользуются,
# * сколько стоит привлечение пользователей из различных рекламных каналов;
# * сколько денег приносит каждый клиент,
# * когда расходы на привлечение клиента окупаются,
# * какие факторы мешают привлечению клиентов.
#
#
# Описание данных
#
# В вашем распоряжении три датасета. Файл visits_info_short.csv хранит лог сервера с информацией о посещениях сайта, orders_info_short.csv — информацию о заказах, а costs_info_short.csv — информацию о расходах на рекламу.
#
#
# Структура visits_info_short.csv:
# * `User Id` — уникальный идентификатор пользователя,
# * `Region` — страна пользователя,
# * `Device` — тип устройства пользователя,
# * `Channel` — идентификатор источника перехода,
# * `Session Start` — дата и время начала сессии,
# * `Session End` — дата и время окончания сессии.
#
#
# Структура orders_info_short.csv:
# * `User Id` — уникальный идентификатор пользователя,
# * `Event Dt` — дата и время покупки,
# * `Revenue` — сумма заказа.
#
#
# Структура costs_info_short.csv:
# * `dt` — дата проведения рекламной кампании,
# * `Channel` — идентификатор рекламного источника,
# * `costs` — расходы на эту кампанию.

# %% [markdown]
# ### Загрузка данных и подготовка их к анализу

# %% [markdown]
# Загружаем данные о визитах, заказах и рекламных расходах из CSV-файлов.
#
# Изучите данные и выполните предобработку. Есть ли в данных пропуски и дубликаты? Убедитесь, что типы данных во всех колонках соответствуют сохранённым в них значениям. Обратите внимание на столбцы с датой и временем.

# %%
# импортирую необходимые библитеки
import pandas as pd
from datetime import datetime, timedelta
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

#указываю путь к датасетам
try:
    visits = pd.read_csv('/datasets/visits_info_short.csv')
    orders = pd.read_csv('/datasets/orders_info_short.csv')
    costs = pd.read_csv('/datasets/costs_info_short.csv')
    
except :
    visits = pd.read_csv('visits_info_short.csv')
    orders = pd.read_csv('orders_info_short.csv')
    costs = pd.read_csv('costs_info_short.csv')

# %% [markdown]
# #### Ознакамливаюсь со структурой данных
# Проверю на пропуски, дубликаты, формат данных. Название колонок приведу к стандарту.

# %%
display(visits.head(),orders.head(),costs.head())
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# ...

# %% [markdown]
# #### Определяю наличие пропусков и формат данных

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# #### Привожу название столбцов к нижнему регистру

# %%
visits.columns = visits.columns.str.lower()
orders.columns = orders.columns.str.lower()
costs.columns = costs.columns.str.lower()

# %% [markdown]
# #### Переименовываю название колонок с датами и ID

# %%
visits = visits.rename(columns={'user id': 'user_id','session start': 'session_start', 'session end': 'session_end'})
orders = orders.rename(columns={'user id': 'user_id','event dt': 'event_dt'})

# %% [markdown]
# #### Привожу временные колонки  во временной формат

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# #### Проверяю на наличие дубликатов явных

# %%
display(visits.duplicated().value_counts(), 
        orders.duplicated().value_counts(), 
        costs.duplicated().value_counts())
# Out:
# False    309901
# dtype: int64
# False    40212
# dtype: int64
# False    1800
# dtype: int64

# %% [markdown]
# #### Проверяю наличие неявных

# %%
display(
        visits['region'].unique(),
        visits['device'].unique(),
        visits['channel'].unique(),
        costs['channel'].unique()
       )
# Out:
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)
# array(['iPhone', 'Mac', 'Android', 'PC'], dtype=object)
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)
# array(['FaceBoom', 'MediaTornado', 'RocketSuperAds', 'TipTop', 'YRabbit',
#        'AdNonSense', 'LeapBob', 'OppleCreativeMedia', 'WahooNetBanner',
#        'lambdaMediaAds'], dtype=object)

# %% [markdown]
# На данном этапе данные подготовлены для дальнейшей работы. Дубликатов и пропусков не обнаружено, форматы данных готовы к вычислениям, название столбцов переименованы для удобства.

# %% [markdown]
# ### Задаю функции для расчёта и анализа LTV, ROI, удержания и конверсии.
#
# Функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# Функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %% [markdown]
# #### Проводим когортный анализ

# %% [markdown]
# ##### Создаём профили пользователей
# Использую фунцию `get_profiles`, в которой сопостовляем зарегестрированных посетителей с посетителями которые совершили покупку

# %%
def get_profiles(visits, orders, costs):
    
    #группируем id пользовтелей и его посещения, выбираем только первые упоминания
    profiles = (
        visits.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'}) #переименовываем колонку
        .reset_index()
    )
    
    #для дальнейшего использования данного датасета меняем формат даты
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')
    
    
    # на данном этапе сравниваем id из visits с совпадениями из orders и записываем признак в отдельную колонку
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'])
    

    # Создаем список всех пользователей. Группируем уникальные id по дате первого посещения и каналу привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем новую таблицу с датасетом расходов
    costs = costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим  расходы на число привлечённых пользователей
    costs['acquisition_cost'] = costs['costs'] / costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)



    return profiles

# %% [markdown]
# ##### Подсчитываем Retention Rate
# Т.е. сколько пользователей из когорты относительно их изначального числа вернулись, то есть воспользовались продуктом или услугой, в последующие периоды. Другими словами это функция для расчета удержания

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ##### Расчет конверсии CR
# Конверсия — это доля людей, перешедших из одного состояния в другое, т.е. это процент пользователей когорты, совершивших какое-нибудь действие

# %%
def get_conversion(
    profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_orders = (
        orders.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_orders[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ##### Подсчет LTV и ROI, CAC
# LTV - это «пожизненная ценность» клиента, то есть общая сумма денег, которую один клиент в среднем приносит компании со всех своих покупок. ROI на сколько процентов «окупились» клиенты и CAC  стоимость привлечения одного клиента

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# #### Визуализация когортного анализа

# %% [markdown]
# ##### filter_data() — для сглаживания данных

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ##### Функция для построения графика Retention Rate

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ##### функция для построения графика конверсии

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# #####  функция  для визуализации LTV и ROI

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True,ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Исследовательский анализ данных
# Составляем профили пользователей.
#
# * Определите минимальную и максимальную даты привлечения пользователей.
#
#
# * Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
#
#
# * Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
#
#
# * Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.

# %% [markdown]
# #### Минимальная и максимальная дата привлечения пользователей.

# %%
#использую заготовленную функцию get_profiles(), передавая ей данные из датасетов о визитах, заказов и тратах
#собираю данные в profiles
profiles = get_profiles(visits, orders,costs)
profiles
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01 09:58:33       organic  iPhone         France
# 3           22593348 2019-08-22 21:35:48    AdNonSense      PC        Germany
# 4           31989216 2019-10-02 00:07:44       YRabbit  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 150003  999956196527 2019-09-28 08:33:02        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21 00:35:17       organic      PC             UK
# 150005  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %%
#создаю переменную в которой сохраню общее количество пользователей
user_num = profiles['user_id'].count()

# %%
# из датасета visits найдем минимальную и максимальную дату,
#но перед этим создаю колонку с датой первого посещения без времени
visits['dt'] = visits['session_start'].dt.date
min_date = visits['dt'].min()
max_date = visits['dt'].max()
display(f"Минимальная дата привлечения пользователей {min_date}", 
f"Максимальная дата привлечения пользователей {max_date}")
# Out:
# 'Минимальная дата привлечения пользователей 2019-05-01'
# 'Максимальная дата привлечения пользователей 2019-10-31'

# %% [markdown]
# Получаем диапазон дат с 1 мая 2019 по 31 октября 2019

# %% [markdown]
# #### Определяю страны с большей долей пользователей совершивших покупки

# %%
#групирую ранее полученный profiles по стране и среднему количеству покуптелей
profiles.groupby('region').agg({'payer':'mean'}).sort_values(by= 'payer', ascending = False)
# Out:
#                   payer
# region
# United States  0.069019
# Germany        0.041119
# UK             0.039829
# France         0.037994

# %%
#группирую по количеству посетителей и покупателей по разбивкам на регионы
vizit_buyer = profiles.pivot_table(
    index='region',  
    columns='payer', 
    values='user_id',  
    aggfunc='count'  
)
#переименую колонки, тем самым сделаю возможным подсчитать проценты
vizit_buyer.columns = ['visitor', 'buyer'] 

#расчитываю проценты

#создаю колонку отображащие общее количество пользователей по странам
vizit_buyer['total']=profiles.pivot_table(
    index='region',  
    values='user_id',  
    aggfunc='count'  
)

#создаю колонку с расчетом числа ползователей в стране, ко всем остальным вместе взятым
vizit_buyer['percent_visitor'] = round((vizit_buyer['total']/user_num)*100,2) 

#какой процент из всех посетителей стали покупателями в каждой стране
vizit_buyer['percent_buyer'] = round((vizit_buyer['buyer']/vizit_buyer['total'])*100,2)

display(vizit_buyer)

profiles.\
pivot_table( index='region',  
             columns='payer', 
            values='user_id',  
            aggfunc='count').\
plot(kind="barh", grid=True)
plt.show()
# Out:
#                visitor  buyer   total  percent_visitor  percent_buyer
# region
# France           16787    663   17450            11.63           3.80
# Germany          14365    616   14981             9.99           4.11
# UK               16875    700   17575            11.72           3.98
# United States    93100   6902  100002            66.66           6.90

# %%
(profiles
    .pivot_table(index='region',  values='payer', aggfunc=['count', 'sum', 'mean'])#группируем по колонке payer,считаем 
                                                                                   #общее количество, сумму True и %
    .reset_index() # сбрасываем индексы
    .rename(columns = {'count':'Пользователи', 'sum': 'Платящие пользователи', 'mean':'% платящих пользователей' })
    .droplevel(1, axis=1)#удаляем лишнее название колонки
    .sort_values(by='Пользователи', ascending=False)#сортируем по количеству пользователей
    .style.format({'% платящих пользователей':'{:.2%}'}) #добавляем к значениям символ процента
)
# Out:
# <style  type="text/css" >
# </style><table id="T_4f00e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >region</th>        <th class="col_heading level0 col1" >Пользователи</th>        <th class="col_heading level0 col2" >Платящие пользователи</th>        <th class="col_heading level0 col3" >% платящих пользователей</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4f00e_level0_row0" class="row_heading level0 row0" >3</th>
#                         <td id="T_4f00e_row0_col0" class="data row0 col0" >United States</td>
#                         <td id="T_4f00e_row0_col1" class="data row0 col1" >100002</td>
#                         <td id="T_4f00e_row0_col2" class="data row0 col2" >6902</td>
#                         <td id="T_4f00e_row0_col3" class="data row0 col3" >6.90%</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# Выводы:
#
# По графику видно что явным лидером становиться US, как по количеству пользователй, так и по количеству покупателей.Остальная тройка не сильно отличается друг от друга по показателям. Проводить аналитику по сравнению с фаворитом будет не совсем корректно, акцентирую внимание на этот момент в будущем.

# %% [markdown]
# #### Какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи

# %%
#Посмотри какие вообще устройства используются посетителями и на их распределение.
profiles.device.value_counts().plot.bar(grid=True)
plt.show()

# %%
#аналогично как и в расчетах выше, составляю сводную таблицу, но делаю акцент на устройство
vizit_device = profiles.pivot_table(
    index='device',  #в строке выбираю разбивку по типу устройства
    columns='payer', #колонку выбираю по признаку покупателя
    values='user_id', 
    aggfunc='count'  #подсчет веду с помощь уникальных id
)

#переименовываю столбцы
vizit_device.columns = ['visitor', 'buyer'] 

#cоздаю столбец с общим количеством устройств
vizit_device['total_device'] = vizit_device['visitor']+vizit_device['buyer']

#какое самое популярное устроство среди всех пользователей
vizit_device['device_percent'] = round((vizit_device['total_device']/vizit_device['total_device'].sum())*100,2)


#какой устройство обладает лучше конверсией?
vizit_device['percent'] = round(vizit_device['buyer']/vizit_device['total_device']*100,2)

display(vizit_device.sort_values('device_percent',ascending = False))

profiles.\
pivot_table( index='payer',  
             columns='device', 
             values='user_id',  
             aggfunc='count').\
plot(kind="barh", grid=True)
plt.show()
# Out:
#          visitor  buyer  total_device  device_percent  percent
# device
# iPhone     51097   3382         54479           36.32     6.21
# Android    32982   2050         35032           23.35     5.85
# PC         28918   1537         30455           20.30     5.05
# Mac        28130   1912         30042           20.03     6.36

# %%
#вывожу самую важную иформацию в отдельную таблицу для лучшей визуализации
vizit_device_sub = vizit_device.drop(columns = ['visitor', 'device_percent' ]).sort_values(by= 'total_device', ascending = False)
vizit_device_sub.columns = ['Платящие пользователи', 'Пользователи', '% платящих пользователей'] 
vizit_device_sub['% платящих пользователей'] =vizit_device_sub['% платящих пользователей'].astype(str) +'%'
display(vizit_device_sub[['Пользователи','Платящие пользователи','% платящих пользователей']],
'Распределние платящих пользователей по фактору: "device"')
# Out:
#          Пользователи  Платящие пользователи % платящих пользователей
# device
# iPhone          54479                   3382                    6.21%
# Android         35032                   2050                    5.85%
# PC              30455                   1537                    5.05%
# Mac             30042                   1912                    6.36%
# 'Распределние платящих пользователей по фактору: "device"'

# %% [markdown]
# Выводы:
#
# Больше всего посетителей зашли в первый раз с iPhone 36.32, на втором месте с результатом 23.35 стоит Android, и практически одинаково распределись PC и Mac. При этом лучшая конверсия 6.36 у Mac, чуть хуже показатель iPhone, на последенм месте PC. Тут, пока что, все кажется вполне закономерным.

# %% [markdown]
# ####  Рекламные источники привлечения и  каналы, из которых пришло больше всего платящих пользователей

# %%
#аналогично как и в расчетах выше, создаю сводную таблицу, но делаю акцент на канал
vizit_channel = profiles.pivot_table(
    index='channel',  #в строке выбираю разбивку по типу канала
    columns='payer', #колонку выбираю по признаку покупателя
    values='user_id', 
    aggfunc='count'  #подсчет веду с помощь уникальных id
)


#переименовываю столбцы
vizit_channel.columns = ['visitor', 'buyer'] 

#cоздаю столбец с общим количеством устройств
vizit_channel['total_channel'] = vizit_channel['visitor']+vizit_channel['buyer']

#какое самое популярное устроство среди всех пользователей
vizit_channel['channel_percent'] = round((vizit_channel['total_channel']/vizit_channel['total_channel'].sum())*100,2)


#какой устройство обладает лучше конверсией?
vizit_channel['percent'] = round(vizit_channel['buyer']/vizit_channel['total_channel']*100,2)

display(vizit_channel.sort_values('channel_percent',ascending = False))

profiles.\
pivot_table(index='channel',  \
            columns='payer', 
            values='user_id',  
            aggfunc='count' ).\
plot(kind='barh', grid= True,title = 'Распределение по каналам',\
      xlabel = 'Канал',ylabel='Количество привлеченых пользвоателей')

plt.show()
# Out:
#                     visitor  buyer  total_channel  channel_percent  percent
# channel
# organic               55279   1160          56439            37.62     2.06
# FaceBoom              25587   3557          29144            19.43    12.20
# TipTop                17683   1878          19561            13.04     9.60
# OppleCreativeMedia     8372    233           8605             5.74     2.71
# LeapBob                8291    262           8553             5.70     3.06
# WahooNetBanner         8100    453           8553             5.70     5.30
# RocketSuperAds         4096    352           4448             2.97     7.91
# MediaTornado           4208    156           4364             2.91     3.57
# YRabbit                4147    165           4312             2.87     3.83
# AdNonSense             3440    440           3880             2.59    11.34
# lambdaMediaAds         1924    225           2149             1.43    10.47

# %% [markdown]
# Т.к. канал органики занимает целую треть привлеченных пользователь, а нам интересено исследовать эффективность трать на каналы, то исключаю естесвенных пользователь из исследования.

# %%
vizit_channel_not_organic = profiles.query('channel != "organic"').pivot_table(
    index='channel',  #в строке выбираю разбивку по типу канала
    columns='payer', #колонку выбираю по признаку покупателя
    values='user_id', 
    aggfunc='count'  #подсчет веду с помощь уникальных id
)


#переименовываю столбцы
vizit_channel_not_organic.columns = ['visitor', 'buyer'] 

#cоздаю столбец с общим количеством устройств
vizit_channel_not_organic['total_channel'] = vizit_channel_not_organic['visitor']+vizit_channel_not_organic['buyer']

#какое самое популярное устроство среди всех пользователей
vizit_channel_not_organic['channel_percent'] = round((vizit_channel_not_organic['total_channel']/vizit_channel_not_organic['total_channel'].sum())*100,2)


#какой устройство обладает лучше конверсией?
vizit_channel_not_organic['percent'] = round(vizit_channel_not_organic['buyer']/vizit_channel_not_organic['total_channel']*100,2)

display(
    vizit_channel_not_organic.sort_values('channel_percent' ,ascending = False),
    vizit_channel_not_organic.sort_values('percent' ,ascending = False))

profiles.\
query('channel != "organic"').pivot_table( index='channel',
columns='payer',
values='user_id',
aggfunc='count' ).\
plot(kind='barh', grid= True,title = 'Распределение по каналам',\
     xlabel = 'Канал',ylabel='Количество привлеченых пользвоателей' )
plt.show()
# Out:
#                     visitor  buyer  total_channel  channel_percent  percent
# channel
# FaceBoom              25587   3557          29144            31.15    12.20
# TipTop                17683   1878          19561            20.91     9.60
# OppleCreativeMedia     8372    233           8605             9.20     2.71
# LeapBob                8291    262           8553             9.14     3.06
# WahooNetBanner         8100    453           8553             9.14     5.30
# RocketSuperAds         4096    352           4448             4.75     7.91
# MediaTornado           4208    156           4364             4.66     3.57
# YRabbit                4147    165           4312             4.61     3.83
# AdNonSense             3440    440           3880             4.15    11.34
# lambdaMediaAds         1924    225           2149             2.30    10.47
#                     visitor  buyer  total_channel  channel_percent  percent
# channel
# ...

# %%
#вывожу самую важную иформацию в отдельную таблицу для лучшей визуализации
vizit_channel_sub = vizit_channel_not_organic.drop(columns = ['visitor', 'channel_percent' ]).sort_values(by= 'total_channel', ascending = False)
vizit_channel_sub.columns = ['Платящие пользователи', 'Пользователи', '% платящих пользователей'] 
vizit_channel_sub['% платящих пользователей'] =vizit_channel_sub['% платящих пользователей'].astype(str) +' %'
display(vizit_channel_sub[['Пользователи','Платящие пользователи','% платящих пользователей']],
'Распределние платящих пользователей по фактору: "channel"')
# Out:
#                     Пользователи  Платящие пользователи  \
# channel
# FaceBoom                   29144                   3557
# TipTop                     19561                   1878
# OppleCreativeMedia          8605                    233
# LeapBob                     8553                    262
# WahooNetBanner              8553                    453
# RocketSuperAds              4448                    352
# MediaTornado                4364                    156
# YRabbit                     4312                    165
# AdNonSense                  3880                    440
# lambdaMediaAds              2149                    225
#
#                    % платящих пользователей
# channel
# FaceBoom                             12.2 %
# TipTop                                9.6 %
# OppleCreativeMedia                   2.71 %
# LeapBob                              3.06 %
# WahooNetBanner                        5.3 %
# RocketSuperAds                       7.91 %
# ...

# %% [markdown]
# Вывод:
#
# * Больше всего в глаза бросается органический канала. 37,2 % пользователей пришли сами, однако покупателей из всей это массы всего 2,06.
#
#
# * Если исключить из исследования естесвенный приток пользователей, то лидерами станут каналы `FaceBoom` и `TipTop`, которые в сумме привели чуть больше половину пользователей. Первый с конверсией  12.20%, второй 11.34%.
#
#
# * Так же хотелось бы выделить канала `lambdaMediaAds`, у которого конверсия 10.47%, при небольшим притоке пользователей всего 2.30, а это худший результат из всех по привлечению в количественном исчестлении.

# %% [markdown]
# ### Маркетинг

# %% [markdown]
# * Посчитайте общую сумму расходов на маркетинг.
#
#
# * Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
#
#
# * Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике.
#
#
# * Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
#
#
# Напишите промежуточные выводы.

# %% [markdown]
# #### Общая сумма расходов на маркетинг

# %%
#суммиуем все значения колонки costs из датасета costs
total_costs = round(costs['costs'].sum(),2)
total_costs
# Out:
# 105497.3

# %% [markdown]
# #### Cколько денег потратили на каждый источник

# %%
#групипрую данные по затратам
total_costs_chanel = costs.pivot_table(index='channel', 
                                       values='costs', 
                                       aggfunc='sum').sort_values('costs',ascending = False)
total_costs_chanel
# Out:
#                        costs
# channel
# TipTop              54751.30
# FaceBoom            32445.60
# WahooNetBanner       5151.00
# AdNonSense           3911.25
# OppleCreativeMedia   2151.25
# RocketSuperAds       1833.00
# LeapBob              1797.60
# lambdaMediaAds       1557.60
# MediaTornado          954.48
# YRabbit               944.22

# %%
#объединяю полученные данные с предьидущими вычислениями, а именно с конверсией 
total_costs_chanel_merge = (
                            vizit_channel_not_organic.
                            merge(total_costs_chanel, on=['channel'], how='outer').
                            sort_values('costs',ascending = False)
                            )


# упорядачива для визуализации сначала по сумме затрат, потом по окупаемости
display(total_costs_chanel_merge[['costs','percent']].sort_values('costs',ascending = False),
        total_costs_chanel_merge[['costs','percent']].sort_values('percent',ascending = False))
# Out:
#                        costs  percent
# channel
# TipTop              54751.30     9.60
# FaceBoom            32445.60    12.20
# WahooNetBanner       5151.00     5.30
# AdNonSense           3911.25    11.34
# OppleCreativeMedia   2151.25     2.71
# RocketSuperAds       1833.00     7.91
# LeapBob              1797.60     3.06
# lambdaMediaAds       1557.60    10.47
# MediaTornado          954.48     3.57
# YRabbit               944.22     3.83
#                        costs  percent
# channel
# FaceBoom            32445.60    12.20
# AdNonSense           3911.25    11.34
# lambdaMediaAds       1557.60    10.47
# TipTop              54751.30     9.60
# RocketSuperAds       1833.00     7.91
# WahooNetBanner       5151.00     5.30
# YRabbit               944.22     3.83
# MediaTornado          954.48     3.57
# LeapBob              1797.60     3.06
# OppleCreativeMedia   2151.25     2.71

# %% [markdown]
# По 1-ой таблице видно, что самые большие вложения были у `TipTop`, однако по окупаемости во 2-ой таблице он занимает лишь 4-ое место. Далее идет `FaceBoom` по затрам, который уже на первом месте по окупаемости.
#
# Итого самые окупаемые **(без учета суммы вложений в 1 покупателя)** `FaceBoom`, `AdNonSense`,`lambdaMediaAds`. Сумма вложений в них менше чем в TipTop, но результат хуже в 3 раза, поэтому можно считать это самым провальным каналом.

# %% [markdown]
# #### Визуализация динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику

# %%
# для этого добавляю 2 новых столбца, с номером месеяца и недели, в таблицу costs
costs['month'] = costs['dt'].astype('datetime64[M]').dt.month
costs['week'] = pd.DatetimeIndex(costs['dt']).week

# и группирую по месяцу
costs_month = costs.pivot_table(index='channel', columns = 'month', values = 'costs', aggfunc='sum')
month = plt.subplot(2,2,1)
costs_month.T.plot(figsize = (12,15), grid = True, ax = month )


plt.title('Визуализация динамики изменения расходов по месяцам в разных каналах')
plt.xlabel('Месяц')
plt.ylabel('Сумма затрат')
plt.show()

#и по неделе
costs_week = costs.pivot_table(index='channel', columns = 'week', values = 'costs', aggfunc='sum')

week = plt.subplot(2,2,2 , sharey = month)
costs_week.T.plot(figsize = (12,15), grid = True, ax = week )

plt.title('Визуализация динамики изменения расходов по неделям в разных каналах')
plt.xlabel('Неделя')
plt.ylabel('Сумма затрат')

plt.show()
# Out:
# /tmp/ipykernel_190/2151398981.py:3: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   costs['week'] = pd.DatetimeIndex(costs['dt']).week

# %% [markdown]
# По графикам видно что практически для всех каналов финансирование было достаточно стабильным, одна из общей картины выделются 2: TipTop  и FaceBoom. Еще замечается одна особенность на недельном графике, а именно как эти 2 канала синхронно повторяются формой графика. Хотя, возможно, это из-за масштаба и менее финансируем каналы делают так же.

# %% [markdown]
# #### Средняя цена привлечения одного пользователя (CAC) из каждого источника

# %%
# в исследовании органического канала сейчас смысла нет, поэтому его исключаем
chanel_cac = profiles.query('channel != "organic"').\
pivot_table( index='channel',
values='acquisition_cost', 
aggfunc='mean' ).\
sort_values('acquisition_cost', ascending = False)

display(chanel_cac)
chanel_cac.plot(kind='barh', grid= True,title = 'Средние затраны на привлечение пользователя',xlabel = 'Каналы',ylabel='Величина затрат') 
plt.show()
# Out:
#                     acquisition_cost
# channel
# TipTop                      2.799003
# FaceBoom                    1.113286
# AdNonSense                  1.008054
# lambdaMediaAds              0.724802
# WahooNetBanner              0.602245
# RocketSuperAds              0.412095
# OppleCreativeMedia          0.250000
# YRabbit                     0.218975
# MediaTornado                0.218717
# LeapBob                     0.210172

# %% [markdown]
# В очередной раз  убеждаемся что на TipTop уходит слишком много денег. В 2 раза больше, чем ближайший в данном рейтинге канал.

# %% [markdown]
# ### Оцените окупаемость рекламы

# %% [markdown]
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
#
#
# *  Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
#
#
# * Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.
#
#
# * Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#
#
# * Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#
#
# * Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#
#
# * Ответьте на такие вопросы:
#
#         Окупается ли реклама, направленная на привлечение пользователей в целом?
#
#         Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#
#         Чем могут быть вызваны проблемы окупаемости?
#
#
# Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.

# %%
#Стартавую дату берем горизонт анализа берем из задания
observation_date = datetime(2019, 11, 1).date()  
horizon_days = 14 

#Как я не учитывал ранее, а сейчас окончатель убираю из исследования органических пользователей
profiles = profiles.query('channel !="organic"')

# %% [markdown]
# #### Визуализирую данные с помощью графических функций

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# * По графикиу LTV наблюдаются скачки со схожей амплитудой, заметны пики в середине месяце
# * График ROI показывает, что средства потраченные на рекламу не окупаются, но так было не всегда. Что-то произошло в июне
# * Динамика стоимости привлечения указывают на колосальный рост трат на привличение, а динамика ROI указывает, что делается это зря

# %% [markdown]
# #### Проверка конверсию пользователей и динамику её изменения

# %%
dimensions = ['channel']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Если смотреть по всем каналам они показывают неплохую конверсеию. Однак, я возьму самые "интересные" примеры из иследований выше и рассмотрю их детальнее

# %%
triger_chanel = ['FaceBoom','TipTop','AdNonSense','lambdaMediaAds' ]

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles.query('channel in @triger_chanel'), orders, observation_date, horizon_days, dimensions=dimensions
)
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Как и впредьидущих исследованиях по конверсии видно что FaceBoom выше остальных, и самый низкий показатель у TipTop.
# На графики конверсии заментны сильнейшие скачки у lambdaMediaAds, в то время как остальне ведутся себя спокойнее.

# %% [markdown]
# #### Анализируем окупаемость рекламы с разбивкой по устройствам

# %%
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days,dimensions=dimensions
)
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days) 

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
#посмотрим на графики удержания
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# *  Окупается реклама лишь на PC, мобильные утсроства хуже всего
# *  При этом траты на рекламу на  PC растут не так сильно, по сравнению с MAC и Iphone
# *  LTV c достаточно стабилен
# *  Самое высокое удрежание на PС

# %% [markdown]
# #### Анализируем окупаемость рекламы с разбивкой по странам

# %%
dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days,dimensions=dimensions
)
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# В вот это самый интересный момент. Как я уже писал в пункте 3.2, что US явно выбивается из общей картины.
# * По графики ROI только US не окупается вовсе
# * По CAC видно, что в UK траты выросли более, чем в 2 раза, в то время как в Европе сократились

# %%
#посмотрим на графики удержания
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# В чоередной раз выделяетя US , показывающее худший результат в удержании платящик пользователей.

# %% [markdown]
# #### Анализируем окупаемость рекламы с разбивкой по каналам

# %%
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days,dimensions=dimensions
)
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
#  * Несмотря на то что FaceBoom обладается самой высокой конверсей привлеченных пользователй(см.п.4.2), затраты все равно не окупаются, с такими же каналами как TipTop, AdNonSense
#  * В п. 3.4 я уже отдельно выделял lambdaMediaAds, сейчас она яркво выражена в динамике LTV
#  * По динамике CAC в очередной раз мы видим виновника колосальных трат, канал CAC. Все остальные стабильны, а у него с каждым месяцем затраты растут ступечато, на одно и ту же похожую сумму.

# %%
#посмотрим на графики удержания
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# FaceBoom и AdNonSense на графике удержания платящих пользователей показываю наихудщие показатели.

# %% [markdown]
# ##### Что если сравнить каналы US и других стран?

# %%
#### Посмотрим на графики profiles в котором только Европа
dimensions = ['channel']
country_US = ['United States']



ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('region not in @country_US'), orders, observation_date, horizon_days,dimensions=dimensions
)

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles.query('region not in @country_US'), orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days) 
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# В Европе лишь 1 канал который не окупается - `AdNonSense` и самый эффективный, который я ранее упомянал `lambdaMediaAds`. Если говорить про рекламные бюджеты, то они достаточно стабильны в данном временном разрезе

# %%
#### Посмотрим на графики profiles в котором только US
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('region in @country_US'), orders, observation_date, horizon_days,dimensions=dimensions
)

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles.query('region in @country_US'), orders, observation_date, horizon_days, dimensions=dimensions
)


plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days) 
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Тут 2 ауйтсайдера Tip Top и FaceBoom, и их, кстати, из нет в Европе. При это,возможно, Tip Top не укпается по причине постоянного вливания средства, а вот FaceBoom в этом плане стабилен. Ну а график конверсии подтверждает вышесказанное, эти убытычные каналы на 0-м дне начинают свое движение с гораздо более высокого показателя.

# %% [markdown]
# ### Общие выводы

# %% [markdown]
# У компании **Procrastinate Pro+**, достаточно хорошие продукты о чем свидетельствует большой органический приток в 37.62% среди общего объема. Однако, компания зарабатывает на этом лишь на 2.06% пользователь. Именно поэтому и приходиться прибегать к услугам различных каналов по привлечению новых пользователей. В Европейской части их 5, такое же количество и в Америке. К тому же из п. 3.2 на штаты приходится 66% пользователей. Поэтому, я считаю, что анализировать их надо по отдельности, что я и сделал в 5.5.1.
#
# В Европе не без проблем. Канал `AdNonSense` не окупается и при этом на его финансирование уходит больше всего финансов. Его конверсия составляет хорошую цифру в 11.34%, но `lambdaMediaAds` дает 10,47% и тратить при этом на треть меньше средств. Я бы порекомендовал связаться с их представителями и попробовать понизить их стоимость услуг, в противном случает отказаться от сотрудничества. В остальном, явных проблем, мной не было увидено.
#
# Если посмотреть на графики от Американских коллег, то сразу становится понятно, почему компания терпит убытки. 2 самых затратных канала `FaceBoom` и `ТipTop`. Если со вторым я могу дать рекомендацию поступить также как у европейских коллег с `AdNonSense`, то с `ТipTop` нужно проводить целое расследование.
#
# 1. Почему финансирование увеличилось?
#
# 2. Почему оно с каждым месяцем планомерно росло ?
#
# 3. Почему никто не проанализоровал эти вложения хотя бы на 2-ой месяц. Вообще странно, что после 1 месяца никто не провел аналитику окупаемости роста их услуг?
#
# В чем я точно уверен, что первым делом стоит распрощаться с каналом `ТipTop`. Это позволит сократить убытки. А так же встретиться  `Yrabbit` с целью налаживания более тесного сотрудничества.
